# %% [markdown]
# en cok gecen kelimeyi daha belirgin yapacak sekilde sanat eseri yapiyoruz

# %%
#pip install stylecloud
# Out:
# Collecting stylecloud
#   Downloading stylecloud-0.5.2.tar.gz (262 kB)
# Requirement already satisfied: wordcloud in c:\users\kemal\anaconda3\lib\site-packages (from stylecloud) (1.8.2.2)
# Collecting icon-font-to-png
#   Downloading icon_font_to_png-0.4.1-py2.py3-none-any.whl (161 kB)
# Collecting palettable
#   Downloading palettable-3.3.0-py2.py3-none-any.whl (111 kB)
# Collecting fire
#   Downloading fire-0.4.0.tar.gz (87 kB)
# Requirement already satisfied: matplotlib in c:\users\kemal\anaconda3\lib\site-packages (from stylecloud) (3.5.1)
# Requirement already satisfied: six in c:\users\kemal\anaconda3\lib\site-packages (from fire->stylecloud) (1.16.0)
# Requirement already satisfied: termcolor in c:\users\kemal\anaconda3\lib\site-packages (from fire->stylecloud) (2.0.1)
# Requirement already satisfied: Pillow>=4.0.0 in c:\users\kemal\anaconda3\lib\site-packages (from icon-font-to-png->stylecloud) (9.0.1)
# Requirement already satisfied: requests>=2.12.5 in c:\users\kemal\anaconda3\lib\site-packages (from icon-font-to-png->stylecloud) (2.27.1)
# Requirement already satisfied: tinycss>=0.4 in c:\users\kemal\anaconda3\lib\site-packages (from icon-font-to-png->stylecloud) (0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kemal\anaconda3\lib\site-packages (from requests>=2.12.5->icon-font-to-png->stylecloud) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kemal\anaconda3\lib\site-packages (from requests>=2.12.5->icon-font-to-png->stylecloud) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\kemal\anaconda3\lib\site-packages (from requests>=2.12.5->icon-font-to-png->stylecloud) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\kemal\anaconda3\lib\site-packages (from requests>=2.12.5->icon-font-to-png->stylecloud) (1.26.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kemal\anaconda3\lib\site-packages (from matplotlib->stylecloud) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\kemal\anaconda3\lib\site-packages (from matplotlib->stylecloud) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kemal\anaconda3\lib\site-packages (from matplotlib->stylecloud) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\kemal\anaconda3\lib\site-packages (from matplotlib->stylecloud) (3.0.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\kemal\anaconda3\lib\site-packages (from matplotlib->stylecloud) (1.21.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\kemal\anaconda3\lib\site-packages (from matplotlib->stylecloud) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\kemal\anaconda3\lib\site-packages (from matplotlib->stylecloud) (0.11.0)
# Building wheels for collected packages: stylecloud, fire
#   Building wheel for stylecloud (setup.py): started
#   Building wheel for stylecloud (setup.py): finished with status 'done'
#   Created wheel for stylecloud: filename=stylecloud-0.5.2-py3-none-any.whl size=259509 sha256=83d5bbee1e3b763299c2c2f76fa3a26bb70c9b40da4988f8229be9c6e811c5fc
#   Stored in directory: c:\users\kemal\appdata\local\pip\cache\wheels\c5\8e\e8\d4fa02f02bc4eea452ff7722f5166d84b41d0c465beeed67cf
#   Building wheel for fire (setup.py): started
#   Building wheel for fire (setup.py): finished with status 'done'
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115942 sha256=77033a1397aa1f16f40b3359401c27c6cd3e022823981905a630ed1c0d178933
#   Stored in directory: c:\users\kemal\appdata\local\pip\cache\wheels\2a\93\86\8cd17bc6c40fb605c3ac549d0b860ef7e84ee5f67bf01a3287
# Successfully built stylecloud fire
# Installing collected packages: palettable, icon-font-to-png, fire, stylecloud
# Successfully installed fire-0.4.0 icon-font-to-png-0.4.1 palettable-3.3.0 stylecloud-0.5.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import stylecloud as sc
sc.gen_stylecloud(file_path = 'challenge.txt', output_name="ch.png")

# %%
from IPython.display import Image
Image(filename="ch.png")
#hic bir sey belirlemesek bayrak sekilde yapiyorb

# %%
import stylecloud

stylecloud.gen_stylecloud(file_path='challenge.txt',
                          icon_name="fas fa-dog",
                          palette='colorbrewer.diverging.Spectral_11',
                          background_color='black',
                          gradient='horizontal', output_name='ch3.png')

# %%
from IPython.display import Image
Image(filename='ch3.png')

# %%
stylecloud.gen_stylecloud(file_path='challenge.txt',
                          icon_name="fas fa-apple-alt", output_name='ch4.png')

# %%
from IPython.display import Image
Image(filename='ch4.png')

# %%
stylecloud.gen_stylecloud(file_path='challenge.txt',
                          icon_name="fas fa-car", output_name='ch5.png')

# %%
Image(filename='ch5.png')

# %%
stylecloud.gen_stylecloud(file_path='challenge.txt',
                          icon_name="fas fa-fighter-jet", output_name='ch6.png')

# %%
Image(filename='ch5.png')

# %%
stylecloud.gen_stylecloud(file_path='challenge.txt',
                          icon_name="fas fa-rocket", output_name='ch7.png')

# %%
Image(filename='ch7.png')

# %%
stylecloud.gen_stylecloud(file_path='challenge.txt',
                          icon_name="fas fa-arrow-right", output_name='ch8.png')

# %%
Image(filename='ch8.png')

# %%
stylecloud.gen_stylecloud(file_path='challenge.txt',
                          icon_name="fas fa-heart", output_name='ch9.png')

# %%
Image(filename='ch9.png')

# %%
stylecloud.gen_stylecloud(file_path='challenge.txt',
                          icon_name="fas fa-star-and-crescent", output_name='ch10.png')

#fas fa-cloud,fas fa-cloud-sun-rain, fire-extinguisher, fas fa-lemon

# %%
Image(filename='ch10.png')

# %%
#pip install stop_words
# Out:
# Collecting stop_words
#   Downloading stop-words-2018.7.23.tar.gz (31 kB)
# Building wheels for collected packages: stop-words
#   Building wheel for stop-words (setup.py): started
#   Building wheel for stop-words (setup.py): finished with status 'done'
#   Created wheel for stop-words: filename=stop_words-2018.7.23-py3-none-any.whl size=32911 sha256=1264af9f6f6fa5dc249f0f5da28e1b96ae68921903a0db776259a0e12a941536
#   Stored in directory: c:\users\kemal\appdata\local\pip\cache\wheels\da\d8\66\395317506a23a9d1d7de433ad6a7d9e6e16aab48cf028a0f60
# Successfully built stop-words
# Note: you may need to restart the kernel to use updated packages.Installing collected packages: stop-words
#
# Successfully installed stop-words-2018.7.23

# %%
from stop_words import get_stop_words
stop_words = get_stop_words('english')

# %%
from wordcloud import WordCloud, ImageColorGenerator
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np # create a mask based  on the image we wish to include

my_mask = np.array(Image.open('cloud.png')) # create a wordcloud
wc= WordCloud(background_color='white',
              mask=my_mask,
              collocations=False,
              width=600,
              height=300,
              contour_color='black',
              stopwords=stop_words)

# %%
with open('challenge.txt', 'r') as txt_file:
    texto = txt_file.read()
wc.generate(texto)

# %%
plt.figure(figsize=(20, 10))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
wc.to_file('wordcloud.png')
plt.show()
