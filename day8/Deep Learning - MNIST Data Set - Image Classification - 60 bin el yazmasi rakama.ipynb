# %% [markdown]
# 60k farkli yazi test yapilmis

# %%
#Verileri normallestirme / ölceklendirme

# %%
import pandas as pd

# %%
df=pd.read_csv("heightweight.csv") #teanger'larin boy ve kilo oranlari

# %%
df.head()
#boylar inch, wight pound
#1lb=453g
#85*453/1000 -- 85lb = 38kg
# Out:
#   gender   ageYear  ageMonth  HeightIn  WeightLB
# 0      f  11.91667       143      56.3      85.0
# 1      f  12.91667       155      62.3     105.0
# 2      f  12.75000       153      63.3     108.0
# 3      f  13.41667       161      59.0      92.0
# 4      f  15.91667       191      62.5     112.5

# %%
import seaborn as sns

# %%
sns.scatterplot(df["HeightIn"],df["WeightLB"])
# Out:
# C:\Users\Kemal\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='HeightIn', ylabel='WeightLB'>

# %%
df.corr()
# Out:
#            ageYear  ageMonth  HeightIn  WeightLB
# ageYear   1.000000  1.000000  0.648857  0.634636
# ageMonth  1.000000  1.000000  0.648857  0.634636
# HeightIn  0.648857  0.648857  1.000000  0.774876
# WeightLB  0.634636  0.634636  0.774876  1.000000

# %%
#Veri Standartlastirma / Ölceklendirme
#iki veriye iki sutuna ayni muamele yapmasini saglamak
#farkli rakam olmasina ragmen esit göryür

# %%
df.head()
# Out:
#   gender   ageYear  ageMonth  HeightIn  WeightLB
# 0      f  11.91667       143      56.3      85.0
# 1      f  12.91667       155      62.3     105.0
# 2      f  12.75000       153      63.3     108.0
# 3      f  13.41667       161      59.0      92.0
# 4      f  15.91667       191      62.5     112.5

# %%
df2=df[["ageYear","WeightLB"]]

# %%
df2
# Out:
#       ageYear  WeightLB
# 0    11.91667      85.0
# 1    12.91667     105.0
# 2    12.75000     108.0
# 3    13.41667      92.0
# 4    15.91667     112.5
# ..        ...       ...
# 232  13.66667     112.0
# 233  15.75000     114.0
# 234  13.66667     140.0
# 235  13.91667     107.5
# 236  12.58333      87.0
#
# [237 rows x 2 columns]

# %%
from sklearn.preprocessing import normalize, scale

# %%
data=scale(df2)

# %%
data # simdi iki sutün -1 ve +1 arasinda ama ayni seyi ifade ediyor yukarida df2 gibi
# Out:
# array([[-1.16552514, -0.840635  ],
#        [-0.51288498,  0.19031193],
#        [-0.62166052,  0.34495397],
#        [-0.1865649 , -0.47980357],
#        [ 1.4450355 ,  0.57691704],
#        [ 0.35729973,  0.55114336],
#        [ 1.11871542,  0.13876459],
#        [-1.21991618, -1.66539255],
#        [-0.24095593, -0.35093521],
#        [-1.32868518, -1.69116622],
#        [-1.38307622,  0.13876459],
#        [ 0.73800431,  0.11299091],
#        [-0.40411597,  1.14393785],
#        [-0.83920506, -0.42825623],
#        [-1.16552514, -2.61901847],
#        [-1.05675613, -0.63444561],
#        [ 1.4450355 ,  0.29340663],
#        [-0.78482056, -1.17569276],
#        [-0.9479806 ,  0.7057854 ],
#        [ 0.84677985,  0.65423806],
#        [-1.27430068, -0.840635  ],
#        [-1.32868518, -1.04682439],
#        [-0.02340486, -0.91795602],
#        [ 0.6292353 ,  0.55114336],
#        [ 1.11871542, -0.01587745],
#        [ 0.08536415,  0.11299091],
#        [ 0.57484427, -0.40248255],
# ...

# %%
normaldata=normalize(df2)

# %%
normaldata # bu da 0 ve 1 arasi ama arasindaki oran ayni
# baska avantaji daha var: rakamlar daha kücük oldugu icin bilgisayari daha az yoruyor
# Out:
# array([[0.13883833, 0.99031506],
#        [0.12209554, 0.99251835],
#        [0.11724138, 0.99310345],
#        [0.14430693, 0.98953298],
#        [0.1400864 , 0.99013928],
#        [0.12621466, 0.99200295],
#        [0.14663487, 0.98919069],
#        [0.16902985, 0.98561093],
#        [0.13970967, 0.99019251],
#        [0.16789859, 0.98580427],
#        [0.11069371, 0.99385457],
#        [0.14186764, 0.98988564],
#        [0.10534839, 0.99443538],
#        [0.13233829, 0.99120461],
#        [0.22966597, 0.97326951],
#        [0.13453349, 0.99090905],
#        [0.14713495, 0.98911643],
#        [0.15725448, 0.98755811],
#        [0.10592249, 0.99437439],
#        [0.13045451, 0.9914543 ],
#        [0.13693316, 0.99058029],
#        [0.1425618 , 0.9897859 ],
#        [0.16152349, 0.98686887],
#        [0.12984383, 0.99153446],
#        [0.15089259, 0.98855016],
#        [0.13247733, 0.99118604],
#        [0.15410821, 0.98805398],
#        [0.13274336, 0.99115044],
# ...

# %%
import matplotlib.pyplot as plt

# %%
sns.distplot(data);
# Out:
# C:\Users\Kemal\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import tensorflow as tf

# %%
mnist=tf.keras.datasets.mnist

# %%
print(mnist)
# Out:
# <module 'keras.api._v2.keras.datasets.mnist' from 'C:\\Users\\Kemal\\anaconda3\\lib\\site-packages\\keras\\api\\_v2\\keras\\datasets\\mnist\\__init__.py'>

# %%
(train_images,train_labels),(test_images,test_labels)=mnist.load_data()
# Out:
# ...
# 11490434/11490434 [==============================] - 8s 1us/step

# %%
train_images.shape #60k resim, 28 pixel*28 pixel*1
# Out:
# (60000, 28, 28)

# %%
train_labels
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(train_images[0],cmap='gray') # ilk

# %%
plt.imshow(train_images[-1],cmap='gray') # sondata:image/png;base64,...

# %%
# Normalize Data

# %%
train_images=train_images/255.0
test_images=test_images/255.0

# %%
#Convolutional Neural Netwroks - CNN

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, InputLayer, Reshape, MaxPooling2D, Flatten
#Conv2D deyince CNN bitmis oluyor

# %%
model=Sequential()
model.add(InputLayer(input_shape=(28,28)))
model.add(Reshape(target_shape=(28,28,1)))
model.add(Conv2D(filters=12,kernel_size=(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(10))

#asil resmi okuyan Conv2D, kernel_size = filtre boyu

# %%
model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),optimizer="adam",metrics="accuracy")

# %%
model.fit(train_images,train_labels,validation_split=0.10,epochs=10)
# Out:
# Epoch 1/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.3075 - accuracy: 0.9132 - val_loss: 0.1254 - val_accuracy: 0.9657
# Epoch 2/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.1143 - accuracy: 0.9678 - val_loss: 0.0800 - val_accuracy: 0.9793
# Epoch 3/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0800 - accuracy: 0.9770 - val_loss: 0.0730 - val_accuracy: 0.9813
# Epoch 4/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0645 - accuracy: 0.9812 - val_loss: 0.0669 - val_accuracy: 0.9822
# Epoch 5/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0569 - accuracy: 0.9828 - val_loss: 0.0626 - val_accuracy: 0.9847
# Epoch 6/10
# 1688/1688 [==============================] - 4s 2ms/step - loss: 0.0498 - accuracy: 0.9845 - val_loss: 0.0582 - val_accuracy: 0.9852
# Epoch 7/10
# ...

# %%
_,accuracy=model.evaluate(test_images,test_labels)
#_ hata göstreyiro , evaluate deyine 1. loss 2. accuracy, _, yapmak la 1. skip yaptik
# Out:
# 313/313 [==============================] - 0s 918us/step - loss: 0.0604 - accuracy: 0.9816

# %%
_
# Out:
# 0.06038343533873558

# %%
#MLOPs - Website vb... entegre etme
#heroku
#amazon webservice
