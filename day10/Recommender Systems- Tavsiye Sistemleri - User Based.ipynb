# %% [markdown]
# # User Based Recommender System

# %%
import pandas as pd

# %%
ratings=pd.read_csv("ml-100k/u.data",sep="\t",header=None,names=["user_id","movie_id","rating"],usecols=range(3))
# csv: Coma Seperated Values
# ancak burdaki sey Tab ile ayrilmis(\t var burda)
# sep (seperator) yazinca virgül yapiyor?
# simdide birinci satir veri -> header=None: ilk satiri baslik gibi almiyor
# suan data ok, ama columns names bilmiyoruz
# names= ile isim veriyoruz ancak son sutün ne bilmiyoruz, onu almiyoruz usecols=range(3), son sütunu almadik

# %%
ratings.head()
# Out:
#    user_id  movie_id  rating
# 0      196       242       3
# 1      186       302       3
# 2       22       377       1
# 3      244        51       2
# 4      166       346       1

# %%
movies=pd.read_csv("ml-100k/u.item",sep="|",header=None,encoding="iso-8859-1",names=["movie_id","title"],usecols=range(2))

# %%
movies.head()
# Out:
#    movie_id              title
# 0         1   Toy Story (1995)
# 1         2   GoldenEye (1995)
# 2         3  Four Rooms (1995)
# 3         4  Get Shorty (1995)
# 4         5     Copycat (1995)

# %%
ratings=pd.merge(movies,ratings)

# %%
ratings.head()
# Out:
#    movie_id             title  user_id  rating
# 0         1  Toy Story (1995)      308       4
# 1         1  Toy Story (1995)      287       5
# 2         1  Toy Story (1995)      148       4
# 3         1  Toy Story (1995)      280       4
# 4         1  Toy Story (1995)       66       3

# %%
ratings.title.nunique()
# Out:
# 1664

# %%
import numpy as np

# %% [markdown]
# ### <font color='blue'> Matrix Factorization
# - her film icin sutün aciyoruz
# - sonra bu kullanici hangi filme hangi rating vermis onu görüyrouz

# %%
#Matrix Factorization
movieratings=ratings.pivot_table(index=['user_id'],columns=["title"],values="rating")

# %%
movieratings.head()
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
# 5                              NaN           NaN                    2.0
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# 1                        5.0         NaN                          NaN
# 2                        NaN         NaN                          NaN
# 3                        NaN         2.0                          NaN
# 4                        NaN         NaN                          NaN
# 5                        NaN         NaN                          NaN
#
# title    20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# user_id
# ...

# %%
starwars=movieratings["Star Wars (1977)"]

# %%
starwars.head()
# Out:
# user_id
# 1    5.0
# 2    5.0
# 3    NaN
# 4    5.0
# 5    4.0
# Name: Star Wars (1977), dtype: float64

# %%
movieratings[["101 Dalmatians (1996)","Star Wars (1977)"]].corr()
# Out:
# title                  101 Dalmatians (1996)  Star Wars (1977)
# title
# 101 Dalmatians (1996)               1.000000          0.211132
# Star Wars (1977)                    0.211132          1.000000

# %%
movieratings.corrwith(starwars).sort_values(ascending=False)
# Out:
# C:\Users\Kemal\anaconda3\lib\site-packages\numpy\lib\function_base.py:2683: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\Users\Kemal\anaconda3\lib\site-packages\numpy\lib\function_base.py:2542: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# title
# Man of the Year (1995)                                                               1.0
# Hollow Reed (1996)                                                                   1.0
# Stripes (1981)                                                                       1.0
# Beans of Egypt, Maine, The (1994)                                                    1.0
# Old Lady Who Walked in the Sea, The (Vieille qui marchait dans la mer, La) (1991)    1.0
#                                                                                     ...
# Wonderland (1997)                                                                    NaN
# ...
